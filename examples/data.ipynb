# %% [markdown]
# # Content
#
# - sample generation
# - using `data.interpolate_time_series`
# - using `data.series2matrix`

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "..")
import ts_train.data as tsd

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import ts_train as tst
tst.data
# Out:
# <module 'ts_train.data' from '../ts_train/data.py'>

# %% [markdown]
# ## sample generation

# %%
sample_size = 15
series_x = pd.Series(
    np.random.random_sample(sample_size), 
    index=pd.date_range("1991", periods=sample_size, freq="s")
    )

plt.plot(series_x, ".:")

# %% [markdown]
# ## using `data.interpolate_time_series`

# %%
upsampled_series_x = tsd.interpolate_series(series_x.reset_index(drop=True), sample_size*15)

plt.plot(upsampled_series_x, ".:")

# %% [markdown]
# ## using `data.series2matrix`

# %%
tsd.series2matrix(series_x, w=3, padding="valid")
# Out:
#                             t       t+1       t+2
# 1991-01-01 00:00:00  0.610850  0.346359  0.650274
# 1991-01-01 00:00:01  0.346359  0.650274  0.801422
# 1991-01-01 00:00:02  0.650274  0.801422  0.848970
# 1991-01-01 00:00:03  0.801422  0.848970  0.482551
# 1991-01-01 00:00:04  0.848970  0.482551  0.314865
# 1991-01-01 00:00:05  0.482551  0.314865  0.339906
# 1991-01-01 00:00:06  0.314865  0.339906  0.813720
# 1991-01-01 00:00:07  0.339906  0.813720  0.058470
# 1991-01-01 00:00:08  0.813720  0.058470  0.583764
# 1991-01-01 00:00:09  0.058470  0.583764  0.717323
# 1991-01-01 00:00:10  0.583764  0.717323  0.380486
# 1991-01-01 00:00:11  0.717323  0.380486  0.071503
# 1991-01-01 00:00:12  0.380486  0.071503  0.087702
